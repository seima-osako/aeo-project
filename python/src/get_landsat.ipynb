# %%
import ee
from datetime import datetime
from dotenv import load_dotenv
import geemap
import geopandas as gpd
import os

# %%
EE_PROJECT_ID = os.environ.get("EE_PROJECT_ID")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
ee.Authenticate()
ee.Initialize(project=EE_PROJECT_ID)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
aoi = gpd.read_file("../data/adm_2/lao_admbnda_adm2_ngd_20191112.shp").explode()
aoi_geometry = aoi[aoi["ADM2_EN"] == "Chomphet"]["geometry"].iloc[0]
coords = [list(aoi_geometry.exterior.coords)]
aoi_gee = ee.Geometry.Polygon(coords)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
# Applies scaling factors.
def apply_scale_factors_l5_l7(image):
    optical_bands = image.select("SR_B.").multiply(0.0000275).add(-0.2)
    thermal_bands = image.select("ST_B6").multiply(0.00341802).add(149.0)
    return image.addBands(optical_bands, None, True).addBands(thermal_bands, None, True)


def apply_scale_factors_l8(image):
    optical_bands = image.select("SR_B.").multiply(0.0000275).add(-0.2)
    thermal_bands = image.select("ST_B.*").multiply(0.00341802).add(149.0)
    return image.addBands(optical_bands, None, True).addBands(thermal_bands, None, True)


def add_evi_l5_l7(image):
    # Landsat 5,7: B3(Red), B4(NIR), B1(Blue)
    evi = image.expression(
        "2.5 * ((NIR - RED) / (NIR + 6 * RED - 7.5 * BLUE + 1))",
        {
            "NIR": image.select("SR_B4"),
            "RED": image.select("SR_B3"),
            "BLUE": image.select("SR_B1"),
        },
    ).rename("EVI")
    return image.addBands(evi)


def add_evi_l8(image):
    # Landsat 8: B4(Red), B5(NIR), B2(Blue)
    evi = image.expression(
        "2.5 * ((NIR - RED) / (NIR + 6 * RED - 7.5 * BLUE + 1))",
        {
            "NIR": image.select("SR_B5"),
            "RED": image.select("SR_B4"),
            "BLUE": image.select("SR_B2"),
        },
    ).rename("EVI")
    return image.addBands(evi)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
def mask_qa(image):
    qa = image.select("QA_PIXEL")
    mask = qa.bitwiseAnd(1 << 3).eq(0)
    return image.updateMask(mask)


# Landsat 5 (1990-2011)
dataset_l5 = (
    ee.ImageCollection("LANDSAT/LT05/C02/T1_L2")
    .filterDate("1990-01-01", "2011-12-31")
    .filterBounds(aoi_gee)
    # .filter(ee.Filter.lt("CLOUD_COVER", 70))
    .map(mask_qa)
    .map(apply_scale_factors_l5_l7)
    .map(add_evi_l5_l7)
)

# Landsat 7 (2012-2013)
dataset_l7 = (
    ee.ImageCollection("LANDSAT/LE07/C02/T1_L2")
    .filterDate("2012-01-01", "2013-12-31")
    .filterBounds(aoi_gee)
    #.filter(ee.Filter.lt("CLOUD_COVER", 70))
    .map(mask_qa)
    .map(apply_scale_factors_l5_l7)
    .map(add_evi_l5_l7)
)

# Landsat 8 (2014-2023)
dataset_l8 = (
    ee.ImageCollection("LANDSAT/LC08/C02/T1_L2")
    .filterDate("2014-01-01", "2023-12-31")
    .filterBounds(aoi_gee)
    #.filter(ee.Filter.lt("CLOUD_COVER", 70))
    .map(mask_qa)
    .map(apply_scale_factors_l8)
    .map(add_evi_l8)
)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
def download_image(image, output_dir):
    date = ee.Date(image.get("system:time_start")).format("YYYY-MM-dd").getInfo()
    filename = f"{date}.tif"
    filepath = os.path.join(output_dir, filename)

    image_evi = image.select("EVI")

    geemap.ee_export_image(
        image_evi,
        filepath,
        scale=30,
        region=aoi_gee,
        file_per_band=False,
        crs="EPSG:4326",
    )
    return filename, False
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
getPixels
# Please wait ...
# Data downloaded to /Users/osako/github/aeo-project/python/data/landsat_images/2022-09-20.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-osako/thumbnails/2986d24fa2bf5d42094eaffe1c51555c-c4821bd0afe819904952a1efeccb8b51:getPixels
# Please wait ...
# Data downloaded to /Users/osako/github/aeo-project/python/data/landsat_images/2022-10-06.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-osako/thumbnails/f270e8f8ab604376d2cfe96e86f6e8cc-69d71388c6297554dd59310cb826ec2c:getPixels
# Please wait ...
# Data downloaded to /Users/osako/github/aeo-project/python/data/landsat_images/2022-10-22.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-osako/thumbnails/0d5e6425291410fc3974cde37b9a3348-fc84df58def384b61849ece99f6e50c5:getPixels
# Please wait ...
# Data downloaded to /Users/osako/github/aeo-project/python/data/landsat_images/2022-11-07.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-osako/thumbnails/5884993f902d1a9cd3ddbda4bed87eca-7672b69dd9fa10f6bfa496ae6500d4ed:getPixels
# Please wait ...
# Data downloaded to /Users/osako/github/aeo-project/python/data/landsat_images/2022-11-23.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-osako/thumbnails/f207120548ccebb8cd9561f12b0b0133-b0da9825fb4add1245cb4e2e843353d3:getPixels
# Please wait ...
# Data downloaded to /Users/osako/github/aeo-project/python/data/landsat_images/2022-12-09.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-osako/thumbnails/a78e086c045d4f283349a097cdbc3b94-b2f44664e0f9373fd8e7ca9615011933:getPixels
# Please wait ...
# Data downloaded to /Users/osako/github/aeo-project/python/data/landsat_images/2022-12-25.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-osako/thumbnails/41d5419cf587e5cf71bb3495baa56a6a-b7d72c70939d9af69299e039d3f696fa:getPixels
# Please wait ...
# Data downloaded to /Users/osako/github/aeo-project/python/data/landsat_images/2023-01-10.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-osako/thumbnails/dae685a1a82db78400557466e598461d-fcd617b80baf315f40d2dfeea097ef61:getPixels
# Please wait ...
# Data downloaded to /Users/osako/github/aeo-project/python/data/landsat_images/2023-01-26.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-osako/thumbnails/ef8f2ac00ffd99e939473e6fb3ad51f4-3074df4321c0b199c513244af9bb1123:getPixels
# Please wait ...
# Data downloaded to /Users/osako/github/aeo-project/python/data/landsat_images/2023-02-11.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-osako/thumbnails/3cb7db1f165f0896b6f8e806bc1c6734-51a10f0e26730b871c095ffd5f535511:getPixels
# Please wait ...
# Data downloaded to /Users/osako/github/aeo-project/python/data/landsat_images/2023-02-27.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-osako/thumbnails/bf16108d5cf3f177495f646da736a946-b664a92aa046b636ca0216c2f6fa76fe:getPixels
# Please wait ...
# Data downloaded to /Users/osako/github/aeo-project/python/data/landsat_images/2023-03-15.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-osako/thumbnails/e0d8817066f5cda6221ffd55f6ab1eaf-32c161a19d7a322c9a9f8399f0ac69cc:getPixels
# Please wait ...
# Data downloaded to /Users/osako/github/aeo-project/python/data/landsat_images/2023-03-31.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-osako/thumbnails/6c15c140629a4f1df88ad64ab0066dc1-68655ef43e7341c615b6a70fd22883de:getPixels
# Please wait ...
# Data downloaded to /Users/osako/github/aeo-project/python/data/landsat_images/2023-04-16.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-osako/thumbnails/5e244a302dde1ae57525baaf4cb90f6e-87d7837f3032c46b60a49d075b5f85f8:getPixels
# Please wait ...
# Data downloaded to /Users/osako/github/aeo-project/python/data/landsat_images/2023-05-02.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-osako/thumbnails/e6e781f30e04c07e82113ce7d171836b-4089ba6dff82e4e443bf207b7c76617e:getPixels
# Please wait ...
# Data downloaded to /Users/osako/github/aeo-project/python/data/landsat_images/2023-05-18.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-osako/thumbnails/bb4575f2191c894ee9a8214c18c1c3b0-a597ceec34a258ab8ff13692abc2a7a4:getPixels
# Please wait ...
# Data downloaded to /Users/osako/github/aeo-project/python/data/landsat_images/2023-06-03.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-osako/thumbnails/1dc7fe3b6e6539cd7cd3d983a24647fe-caadb3573f2b9e47a08130b48654d3a2:getPixels
# Please wait ...
# Data downloaded to /Users/osako/github/aeo-project/python/data/landsat_images/2023-06-19.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-osako/thumbnails/acd4f57ae4b850111c3a0dd84b4f437f-c043252f3ae8ae48a6931c9f221fa13b:getPixels
# Please wait ...
# Data downloaded to /Users/osako/github/aeo-project/python/data/landsat_images/2023-07-21.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-osako/thumbnails/e17b372c6e1cb8520bf064fbd358e549-0c9e8ddda4b2dcec619cc6eef701208c:getPixels
# Please wait ...
# Data downloaded to /Users/osako/github/aeo-project/python/data/landsat_images/2023-08-22.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-osako/thumbnails/7d4a32727eb2d65126625eb4b12c1c0f-ef84a4295dc771d6f0f7b91d8f501a22:getPixels
# Please wait ...
# Data downloaded to /Users/osako/github/aeo-project/python/data/landsat_images/2023-09-07.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-osako/thumbnails/9d0d9068badcc90be3a1b4af0f115733-0d405484e0b9a4244c3f5f92474a7a84:getPixels
# Please wait ...
# Data downloaded to /Users/osako/github/aeo-project/python/data/landsat_images/2023-09-23.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-osako/thumbnails/a056ae8cc8182a8f2662feee796e2bf3-cf760bf2c54a62503f309e26e9b3c24f:getPixels
# Please wait ...
# Data downloaded to /Users/osako/github/aeo-project/python/data/landsat_images/2023-10-25.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-osako/thumbnails/1643a4b2a2439b26a050ae36f3ce1d3f-ebb66eea58ca77457ec2f85db59966e1:getPixels
# Please wait ...
# Data downloaded to /Users/osako/github/aeo-project/python/data/landsat_images/2023-11-10.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-osako/thumbnails/dd5be8f5c524cc175c68cb53533ede50-1d60787e4a386695994daabc2ab170f6:getPixels
# Please wait ...
# Data downloaded to /Users/osako/github/aeo-project/python/data/landsat_images/2023-11-26.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-osako/thumbnails/c367b2fcc62e06c46bdefad02ca4a56a-7ad3c64491d86ccc38eeffae8f83896b:getPixels
# Please wait ...
# Data downloaded to /Users/osako/github/aeo-project/python/data/landsat_images/2023-12-12.tif
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-osako/thumbnails/5e666db91ad86ad5effc15cde34547fa-4a8cfe9f8936f0d24d3611e58b8a791f:getPixels
# Please wait ...
# Data downloaded to /Users/osako/github/aeo-project/python/data/landsat_images/2023-12-28.tif

# %%
gfc = ee.Image("UMD/hansen/global_forest_change_2023_v1_11").select(
    ["loss", "lossyear"]
)

geemap.ee_export_image(
    gfc,
    filename="../data/global_forest_change_2023_v1_11.tif",
    scale=30,
    region=aoi_gee,
    crs="EPSG:4326",
    file_per_band=False,
)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Generating URL ...
# Downloading data from https://earthengine.googleapis.com/v1/projects/ee-osako/thumbnails/4446300563c3ec37c078438069f7ce0d-8e3e18b44ff67218c5479fb7a9b0abd2:getPixels
# Please wait ...
# Data downloaded to /Users/osako/github/aeo-project/python/data/global_forest_change_2023_v1_11.tif
